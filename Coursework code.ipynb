# %% [markdown]
# ### Visual Analytics: Coursework by Ekta Khanchandani
# #### Visual analytics on the Zomato Restaurants Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
zomato = pd.read_csv('zomato.csv',encoding="ISO-8859-1")

# %%
zomato.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
zomato.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# ### Joining the country names data by country code

# %%
country = pd.read_excel('Country-Code.xlsx')
data = pd.merge(zomato, country, on='Country Code')
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# ### Grouping the country code to get the number of restaurants

# %%
country_data = data.groupby(['Country'], as_index=False).count()[['Country', 'Restaurant ID']]
country_data.head()
country_data.columns = ['Country', 'No of Restaurant']

# %% [markdown]
# ### Plotting the number of restaurants by country

# %%
plt.bar(country_data['Country'], country_data['No of Restaurant'])
plt.xlabel('Countries', fontsize=25)
plt.rcParams['figure.figsize']=(30,20) 
plt.ylabel('No. of Restaurants', fontsize=25)
plt.title('Number of restaurants by Country', fontsize=30)
# Out:
# Text(0.5, 1.0, 'Number of restaurants by Country')

# %% [markdown]
# ### Plotting the number of restaurants by cities of India

# %%
city_data = data[data['Country'] =='India']
city_data1 = city_data['City'].value_counts()
city_data1.plot.bar(figsize=(14, 7),fontsize=14)
plt.title('No. of restaurants by city (India)', fontsize=30)                                             
plt.xlabel('City', fontsize=20)
plt.ylabel('No. of Restaurants', fontsize=20)
# Out:
# Text(0, 0.5, 'No. of Restaurants')

# %% [markdown]
# Since the data is primarily in India, we will filter out other countries for this part of the analysis

# %% [markdown]
# ### Checking for missing values

# %%
missing_vals = sns.barplot(data=data.isnull().sum().reset_index(), y='index', x=0)

# %% [markdown]
# ### Plotting outliers in the data

# %%
features = data.columns[1:].tolist()

sns.boxplot(data=data[features])
plt.title('Zomato restaurant data outliers')
plt.show()

# %% [markdown]
# ### Filtering out other countries using the country code

# %%
india_data = data[data['Country Code']==1]
india_data.head()
# Out:
#      Restaurant ID                        Restaurant Name  Country Code  City  \
# 624        3400025                             Jahanpanah             1  Agra
# 625        3400341                    Rangrezz Restaurant             1  Agra
# 626        3400005                Time2Eat - Mama Chicken             1  Agra
# 627        3400021  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra
# 628        3400017                         Pinch Of Spice             1  Agra
#
#                                                Address     Locality  \
# 624  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 625  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 626        Main Market, Sadar Bazaar, Agra Cantt, Agra   Agra Cantt
# 627  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...  Civil Lines
# 628  23/453, Opposite Sanjay Cinema, Wazipura Road,...  Civil Lines
#
#       Locality Verbose  Longitude   Latitude                        Cuisines  \
# ...

# %%
india_data['City'].value_counts()
# Out:
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Guwahati          21
# Ahmedabad         21
# Lucknow           21
# Amritsar          21
# Bhubaneshwar      21
# Nashik            20
# Mangalore         20
# Kolkata           20
# Ranchi            20
# Pune              20
# Coimbatore        20
# Dehradun          20
# Surat             20
# Varanasi          20
# Kanpur            20
# Vizag             20
# Kochi             20
# Mysore            20
# Vadodara          20
# Allahabad         20
# Bangalore         20
# Jaipur            20
# Agra              20
# Ludhiana          20
# Puducherry        20
# Indore            20
# Patna             20
# Chennai           20
# Nagpur            20
# Goa               20
# Mumbai            20
# Aurangabad        20
# Bhopal            20
# Chandigarh        18
# Hyderabad         18
# Secunderabad       2
# Panchkula          1
# Mohali             1
# ...

# %% [markdown]
# ### Comparing the price range and ratings by location

# %% [markdown]
# Comparing the price and ratings of restaurants around the world

# %%
pr_r = pd.crosstab(data["Aggregate rating"], data["Price range"])
pr_r.div(pr_r.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,color=['yellow','pink','orange','red'])
plt.xlabel('Aggregate rating', fontsize=25)
plt.ylabel('Price range', fontsize=25)
plt.title('Aggregate ratings of restaurants based on the price range', fontsize=30)
# Out:
# Text(0.5, 1.0, 'Aggregate ratings of restaurants based on the price range')

# %% [markdown]
# Comparing the price and ratings of restaurants in India

# %%
pr_r = pd.crosstab(india_data["Aggregate rating"], india_data["Price range"])
pr_r.div(pr_r.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,color=['yellow','pink','orange','red'])
plt.xlabel('Aggregate rating', fontsize=25)
plt.ylabel('Price range', fontsize=25)
plt.title('Aggregate ratings of restaurants based on the price range', fontsize=30)
# Out:
# Text(0.5, 1.0, 'Aggregate ratings of restaurants based on the price range')

# %% [markdown]
# ### Plotting a correlation matrix to evaluate the relationship between variables

# %% [markdown]
# This will help us identify the variables that impact the rating of restaurants

# %%
correlation = sns.heatmap(data.corr())

# %%
correlation_in = sns.heatmap(india_data.corr())

# %% [markdown]
# ### Mapping the spatial distribution of restaurants based on ratings

# %%
import geopandas as gpd

# %% [markdown]
# Defining a bounding box to set the parameters for the map
# This helps set the parameters using the minimum and maximum values for the longitude and latitude.

# %% [markdown]
# #### Bounding box: World

# %%
World_BBox = (data.Longitude.min(), data.Longitude.max(), data.Latitude.min(), data.Latitude.max())
print(World_BBox)
# Out:
# (-157.948486, 174.8320893, -41.330428000000005, 55.976980000000005)

# %% [markdown]
# #### Bounding box: India

# %%
India_BBox = (india_data.Longitude.min(), india_data.Longitude.max(), india_data.Latitude.min(), india_data.Latitude.max())
print(India_BBox)
# Out:
# (0.0, 91.806493, 0.0, 35.0)

# %% [markdown]
# ### Mapping the spacial distribution of restaurants on Zomato

# %%
xmm = (data.Longitude.min()+data.Longitude.max())/2
ymm = (data.Latitude.min()+data.Latitude.max())/2

# %%
import folium
from folium.plugins import HeatMap

# %%
map = folium.Map(location=[ymm,xmm], zoom_start=6, width=600,height=700)
data.apply(lambda row:folium.CircleMarker(location=[row["Latitude"], row["Longitude"]], 
                                        radius=3, opacity=.05, color='#cc0000').add_to(map), axis=1)
map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-52fd2b968e70> in <module>
#       2 data.apply(lambda row:folium.CircleMarker(location=[row["Latitude"], row["Longitude"]],
#       3                                         radius=3, opacity=.05, color='#cc0000').add_to(map), axis=1)
# ----> 4 ma
#
# NameError: name 'ma' is not defined

# %% [markdown]
# ### Replace the dots by a density map (a.k.a. heatmap)

# %% [markdown]
# This operation represents the spatial distribution as a smooth continuous surface.

# %%
hmap = folium.Map(location=[ymm,xmm], zoom_start=6, width=600,height=700)
hm_wide = HeatMap(list(zip(data.Latitude.values, data.Longitude.values)), 
                  min_opacity=0.2,
                  radius=10, blur=15, 
                  max_zoom=1)
hmap.add_child(hm_wide)

# %% [markdown]
# ### Change the colour scale and the level of smoothing

# %% [markdown]
# We replace the "rainbow" colour scale, which is not recommended for representing numeric data, by a better one.
# The smoothing level is controlled by the value of the parameter 'radius'. Change the value of this parameter to observe its impact on the visible patterns.

# %%
hmap = folium.Map(location=[ymm,xmm], zoom_start=6, width=600,height=700)
hm_wide = HeatMap(list(zip(data.Latitude.values, data.Longitude.values)), 
                  min_opacity=0.2,
                  #radius=5,
                  radius=4.5,
                  blur=10, 
                  #Adjusting the radius will make areas more distict, and reducing blur will make map clearer!
                  max_zoom=1, gradient={.5: 'blue', .75: 'orange', 0.9: 'red'})
hmap.add_child(hm_wide)

# %% [markdown]
# ### Building a linear regression model

# %%
in_data = india_data.drop(columns=['Restaurant ID','Restaurant Name','Country Code', 'City', 'Address', 'Locality', 'Locality Verbose','Longitude', 'Latitude', 'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now','Switch to order menu','Rating color', 'Rating text', 'Country'])

# %%
in_data.head()
# Out:
#      Average Cost for two  Price range  Aggregate rating  Votes
# 624                   850            3               3.9    140
# 625                   700            2               3.5     71
# 626                   500            2               3.6     94
# 627                   400            2               4.0     87
# 628                  1000            3               4.2    177

# %%
X = in_data.drop(columns=['Aggregate rating']).values
Y = in_data['Aggregate rating'].values

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (6921, 3)
# (1731, 3)
# (6921,)
# (1731,)

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()

reg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_predict = reg.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(Y_test,y_predict)
# Out:
# 0.20050827005535266

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
residuals = sns.residplot(x=y_predict, y=Y_test, lowess=True, color="g")

# %% [markdown]
# ### Improving the accuracy of linear regression model

# %%
print("lr.coef_: {}".format(reg.coef_))
print("lr.intercept_: {}".format(reg.intercept_))
print("Training set score: {:.2f}".format(reg.score(X_train, Y_train)))
print("Test set score: {:.7f}".format(reg.score(X_test, Y_test)))
# Out:
# lr.coef_: [-3.27244860e-05  6.41705597e-01  6.05782082e-04]
# lr.intercept_: 1.3662451972864909
# Training set score: 0.19
# Test set score: 0.2005083

# %% [markdown]
# ### Fitting the data to a random forest regressor model to see if it improves accuracy

# %%
from sklearn.linear_model import RidgeCV, LinearRegression, Lasso
from sklearn.ensemble import RandomForestRegressor

reg = RandomForestRegressor(n_estimators=100)

# %%
reg.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %%
print("Training set score: {:.2f}".format(reg.score(X_train, Y_train)))
print("Test set score: {:.2f}".format(reg.score(X_test, Y_test)))
# Out:
# Training set score: 0.98
# Test set score: 0.94

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.errorbar(Y_test, y_predict, fmt='o')
ax.errorbar([1, Y_test.max()], [1, Y_test.max()])
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# Random Forest regressor model perfoms better with improved scores, as opposed to a linear regression model.

# %%
residuals = sns.residplot(x=y_predict, y=Y_test, lowess=True, color="g")
